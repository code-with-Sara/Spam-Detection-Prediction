# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load dataset
df = pd.read_csv("/content/drive/MyDrive/Google Colab/email-spam.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.describe()
# Out:
#        Category                 Message
# count      5572                    5572
# unique        2                    5157
# top         ham  Sorry, I'll call later
# freq       4825                      30

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %% [markdown]
# **Drop the unnamed columns**

# %%
df.isna().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
#create a new solumn name it spam and put its values  to 0 and 1
df['Spam'] = df['Category'].apply(lambda x:1 if x == "spam" else 0)

#let's check the changes
df.head(5)
# Out:
#   Category                                            Message  Spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.Message, df.Spam, test_size=0.25 )

# %%
#let's convert the tex into matrics by using Countervectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# **Naive Bayes Have three Classifier(Bernouli,Multinominal,Gaussian) Here I use Multinominal Bayes Because here data in a discrete form discrete data**

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.pipeline import Pipeline
clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('NB', MultinomialNB())
])

# %% [markdown]
# **Training the Model**

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('NB', MultinomialNB())])

# %% [markdown]
# **I provided two emails one of themis Spam an dother is not spam**

# %%
emails = ["Sounds great! Are you home now?",
          "Your free ringtone is waiting to be collected. Simply text the password 'MIX' to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16"]

# %%
clf.predict(emails)
# Out:
# array([0, 1])

# %% [markdown]
# **Prediction of Model**

# %%
clf.score(X_test, y_test)
# Out:
# 0.9806173725771715
